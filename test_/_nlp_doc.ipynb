# %%
# Importing Libraries 
import numpy as np   
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

# %%
mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
# mpl.rcParams['savefig.dpi']=200             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)
data = pd.read_csv("../sample_data/most_backed.csv")

wordcloud = WordCloud(   stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                         ).generate(str(data['title']))
# print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
data = pd.read_csv("../sample_data/most_backed.csv")

# %%
data.sample(5)
# Out:
#       Unnamed: 0  amt.pledged  \
# 3485        3485      56519.0
# 3703        3703      71999.0
# 1890        1890     203677.0
# 975          975     832523.0
# 1872        1872     324462.0
#
#                                                   blurb  \
# 3485  \nFerment just about anything with this easy-t...
# 3703  \n“NAILED IT!” Behold, the world’s first nail-...
# 1890  \nL8 connects via bluetooth to your smartphone...
# 975   \nStart enjoying quiet nights, better sleep, a...
# 1872  \nSail, raid and conquer! Complete the epic Vi...
#
#                            by        category currency      goal  \
# 3485  Nicole Kramer Easterday            Food      usd   15000.0
# 3703      Espionage Cosmetics         Fashion      usd   20000.0
# 1890            L8 SmartLight         Gadgets      usd   90000.0
# 975           Smart Nora Inc.      Technology      usd  100000.0
# 1872            Shem Phillips  Tabletop Games      nzd   50000.0
#
#                location  num.backers  \
# 3485        Oakland, CA         1240
# 3703         Tacoma, WA         1185
# 1890      San Diego, CA         2021
# 975   San Francisco, CA         3426
# 1872       Waikanae, NZ         2033
#
#                                        num.backers.tier  \
# 3485  [15, 4, 5, 6, 166, 123, 158, 43, 74, 39, 53, 3...
# 3703  [19, 47, 492, 199, 40, 28, 1, 44, 7, 231, 16, ...
# 1890  [28, 8, 6, 1103, 295, 82, 303, 133, 31, 6, 2, ...
# 975   [238, 100, 350, 50, 100, 770, 1490, 13, 36, 50...
# 1872                 [94, 290, 143, 577, 363, 336, 221]
#
#                                             pledge.tier  \
# 3485  [1.0, 8.0, 12.0, 22.0, 25.0, 30.0, 30.0, 33.0,...
# 3703  [1.0, 15.0, 25.0, 50.0, 50.0, 75.0, 75.0, 100....
# 1890  [5.0, 20.0, 25.0, 69.0, 80.0, 99.0, 135.0, 199...
# 975   [1.0, 145.0, 179.0, 179.0, 199.0, 199.0, 239.0...
# 1872       [0.65, 48.0, 56.0, 73.0, 81.0, 162.0, 170.0]
#
#                                                   title  \
# 3485                         FARMcurious Fermenting Set
# 3703                   Espionage Cosmetics "NAILED IT!"
# 1890  L8 SmartLight :: The SoundLess Speaker :: for ...
# 975                    Nora, The Smart Snoring Solution
# 1872                         Explorers of the North Sea
#
#                                                     url
# 3485    /projects/2021939414/farmcurious-fermenting-set
# 3703  /projects/naileditec/espionage-cosmetics-naile...
# 1890  /projects/l8smartlight/l8-smartlight-the-sound...
# 975   /projects/behrouz/nora-the-smart-snoring-solution
# 1872          /projects/shem/explorers-of-the-north-sea

# %%
import nltk
# nltk.download()
